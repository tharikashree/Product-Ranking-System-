# %% [markdown]
# #Product Web Scraper

# %%
import requests
from lxml import html
from pprint import pprint

# %%
def get_html_tree(url, headers=None):
    try:
        response = requests.get(url, headers=headers or {})
        if response.status_code == 200:
            return html.fromstring(response.text)
        else:
            print(f"Failed to fetch {url} - Status code: {response.status_code}")
            return None
    except Exception as e:
        print(f"Error fetching {url}: {e}")
        return None

# %%
def parse_newme(url):
    headers = {"User-Agent": "Mozilla/5.0"}
    tree = get_html_tree(url, headers)
    if tree is None:
        return []

    products = []

    product_divs = tree.xpath('//div[starts-with(@id, "") and div/a]')

    for prod in product_divs:
        try:
            title = ''.join(prod.xpath('.//div/a/div/div/div[2]//text()')).strip()
            if not title:
                continue
            price_texts = [text.strip() for text in prod.xpath('.//div/a/div/div/div[3]/div/div//text()') if text.strip()]
            price = ''.join(price_texts[:2])
            link = prod.xpath('.//a/@href')
            link = "https://newme.asia" + link[0] if link else None

            img = prod.xpath('.//div/a/div/div/div[1]/div[1]/img/@href')
            img = img[0] if img else None

            discount = ''.join(prod.xpath('.//div/a/div/div/div[3]/div/div/div[3]//text()')).strip()

            rating_texts = prod.xpath('.//div[contains(@class, "bg-nm_white")]/text() | .//div[contains(@class, "bg-nm_white")]/span/text()')
            cleaned = [x.strip() for x in rating_texts if x.strip() and x.strip() != '|']
            rating = ''.join(cleaned[:2]) if len(cleaned) >= 2 else None

            text = f"{title} {price} {discount}".strip()

            products.append({
                "product_title": title,
                "product_price": price,
                "product_link": link,
                "product_image_url": img,
                "product_rating": rating or None,
                "product_discount": discount or None,
                "product_text": text
            })
        except Exception as e:
            print("Error parsing product:", e)
            continue

    return products
parse_newme("https://newme.asia/collection/cannes-2025?subCategory=&product_cat=&orderby=menu_order")
# Out:
# [{'product_title': 'Gold Shimmer Gown',
#   'product_price': '₹1599',
#   'product_link': 'https://newme.asia/product/gold-shimmer-gown',
#   'product_image_url': 'https://assets.newme.asia/wp-content/uploads/2024/11/23103344714ed636/NM-PRC-34-DRS-24-NOV-11620-GOLD(1).webp',
#   'product_rating': '★4.4',
#   'product_discount': '16% off',
#   'product_text': 'Gold Shimmer Gown ₹1599 16% off'},
#  {'product_title': 'Imitation Multicolor Drop Earrings',
#   'product_price': '₹199',
#   'product_link': 'https://newme.asia/product/multicolor-rhinestone-embellished-drop-earrings',
#   'product_image_url': 'https://assets.newme.asia/wp-content/uploads/2025/05/17103234c2123f49/NM-PRC-215-ERG-25-FEB-2548-MULTI(1).webp',
#   'product_rating': '★4.7',
#   'product_discount': None,
#   'product_text': 'Imitation Multicolor Drop Earrings ₹199'},
#  {'product_title': 'Beige Shimmer Halter Neck Gown',
#   'product_price': '₹1749',
#   'product_link': 'https://newme.asia/product/beige-shimmer-halter-neck-gown',
#   'product_image_url': 'https://assets.newme.asia/wp-content/uploads/2024/11/1614341565eeb505/NM-PRC-135-DRS-24-NOV-11311-BEIGE(1).webp',
#   'product_rating': '★5.0',
#   'product_discount': '21% off',
#   'product_text': 'Beige Shimmer Halter Neck Gown ₹1749 21% off'},
#  {'product_title': 'Imitation Preppy Choker Necklace With Assorted Charms',
#   'product_price': '₹399',
#   'product_link': 'https://newme.asia/product/preppy-choker-necklace-with-assorted-charms',
#   'product_image_url': 'https://assets.newme.asia/wp-content/uploads/2024/09/1020594343d69f12/NM-PRC-209-NCK-24-SEP-160-MULTI_(1).webp',
#   'product_rating': '★4.6',
#   'product_discount': None,
#   'product_text': 'Imitation Preppy Choker Necklace With Assorted Charms ₹399'},
#  {'product_title': 'Black Cut Out Detail Bodycon Slip Dress',
#   'product_price': '₹1549',
#   'product_link': 'https://newme.asia/product/black-cut-out-detail-bodycon-slip-dress',
#   'product_image_url': 'https://assets.newme.asia/wp-content/uploads/2025/06/02194022c0e84a53/NM-PRC-3-DRS-25-MAR-15035-BLACK(1).webp',
#   'product_rating': '★4.4',
#   'product_discount': '7% off',
#   'product_text': 'Black Cut Out Detail Bodycon Slip Dress ₹1549 7% off'},
#  {'product_title': 'Kardashian Slim Dress',
#   'product_price': '₹799',
#   'product_link': 'https://newme.asia/product/solid-bodycon-maxi-dress',
#   'product_image_url': 'https://assets.newme.asia/wp-content/uploads/2025/06/02163833db8f7933/NM-IN-50-DRS-23-APR-862-BLACK(1)_exp.webp',
#   'product_rating': '★4.6',
#   'product_discount': '41% off',
#   'product_text': 'Kardashian Slim Dress ₹799 41% off'},
#  {'product_title': 'Silver Imitation Chain Link Ring',
#   'product_price': '₹299',
#   'product_link': 'https://newme.asia/product/silver-imitation-chain-link-ring',
#   'product_image_url': 'https://assets.newme.asia/wp-content/uploads/2025/05/17111610f90702a8/NM-PRC-205-RNG-25-FEB-2768-SILVER(1).webp',
#   'product_rating': '★4.4',
#   'product_discount': None,
#   'product_text': 'Silver Imitation Chain Link Ring ₹299'},
#  {'product_title': 'Silver Bodycon Mermaid Dress',
#   'product_price': '₹1049',
#   'product_link': 'https://newme.asia/product/silver-bodycon-mermaid-dress',
#   'product_image_url': 'https://assets.newme.asia/wp-content/uploads/2025/06/241352461fdc38fe/NM-PRC-119-DRS-25-APR-18053-SILVER(1)_exp.webp',
#   'product_rating': '★4.7',
#   'product_discount': '12% off',
#   'product_text': 'Silver Bodycon Mermaid Dress ₹1049 12% off'},
#  {'product_title': 'Silver Imitation Embellished Serpent Ring',
#   'product_price': '₹249',
#   'product_link': 'https://newme.asia/product/silver-imitation-embellished-serpent-ring',
#   'product_image_url': 'https://assets.newme.asia/wp-content/uploads/2025/05/18093844259debaf/NM-PRC-217-RNG-25-MAR-3013-SILVER(1).webp',
#   'product_rating': '★4.7',
#   'product_discount': None,
#   'product_text': 'Silver Imitation Embellished Serpent Ring ₹249'},
#  {'product_title': 'White Solid Halter Neck Sheath Dress',
#   'product_price': '₹1799',
#   'product_link': 'https://newme.asia/product/white-solid-halter-neck-sheath-dress',
#   'product_image_url': 'https://assets.newme.asia/wp-content/uploads/2025/05/171648555e5837d7/NM-PRC-154-DRS-25-MAR-15595-WHITE(1).webp',
#   'product_rating': '★5.0',
#   'product_discount': '9% off',
#   'product_text': 'White Solid Halter Neck Sheath Dress ₹1799 9% off'},
#  {'product_title': 'Silver Imitation Butterfly Shaped Ring',
#   'product_price': '₹199',
#   'product_link': 'https://newme.asia/product/silver-imitation-butterfly-shaped-ring-2',
#   'product_image_url': 'https://assets.newme.asia/wp-content/uploads/2025/05/1809435803e18a0d/NM-PRC-209-RNG-25-MAR-3045-SILVER(1).webp',
#   'product_rating': '★4.4',
#   'product_discount': None,
#   'product_text': 'Silver Imitation Butterfly Shaped Ring ₹199'},
#  {'product_title': 'Bustier Corset Top',
#   'product_price': '₹989',
#   'product_link': 'https://newme.asia/product/bustier-corset-top-2',
#   'product_image_url': 'https://assets.newme.asia/wp-content/uploads/2025/05/2008323439b1067f/NM-PRC-34-BLS-23-JUN-815-APRICOT(1)_exp.webp',
#   'product_rating': '★4.8',
#   'product_discount': None,
#   'product_text': 'Bustier Corset Top ₹989'},
#  {'product_title': 'Imitation Elegant Stud Earrings',
#   'product_price': '₹449',
#   'product_link': 'https://newme.asia/product/imitation-elegant-stud-earrings-2',
#   'product_image_url': 'https://assets.newme.asia/wp-content/uploads/2025/05/181147155daa388c/NM-PRC-213-ERG-25-MAY-18807-GOLD_(1).webp',
#   'product_rating': '★4.7',
#   'product_discount': '19% off',
#   'product_text': 'Imitation Elegant Stud Earrings ₹449 19% off'},
#  {'product_title': 'Gold Imitation Sun Charm Bracelet',
#   'product_price': '₹349',
#   'product_link': 'https://newme.asia/product/gold-imitation-sun-charm-bracelet',
#   'product_image_url': 'https://assets.newme.asia/wp-content/uploads/2025/05/171032552ce76db2/NM-PRC-204-BRC-25-FEB-2653-GOLD(1).webp',
#   'product_rating': '★4.7',
#   'product_discount': '13% off',
#   'product_text': 'Gold Imitation Sun Charm Bracelet ₹349 13% off'},
#  {'product_title': 'Maroon Lace Detail Aline Maxi Skirt',
#   'product_price': '₹1699',
#   'product_link': 'https://newme.asia/product/maroon-lace-detail-aline-maxi-skirt',
#   'product_image_url': 'https://assets.newme.asia/wp-content/uploads/2025/05/180857506d357302/NM-PRC-138-SKT-25-MAR-15185-MAROON(1).webp',
#   'product_rating': '★4.8',
#   'product_discount': '9% off',
#   'product_text': 'Maroon Lace Detail Aline Maxi Skirt ₹1699 9% off'},
#  {'product_title': 'Imitation Timeless Gold-Plated Layered Necklace',
#   'product_price': '₹399',
#   'product_link': 'https://newme.asia/product/timeless-goldplated-layered-necklace',
#   'product_image_url': 'https://assets.newme.asia/wp-content/uploads/2024/09/10210052b156495c/NM-PRC-209-NCK-24-SEP-187-GOLD_(1).webp',
#   'product_rating': '★5.0',
#   'product_discount': '12% off',
#   'product_text': 'Imitation Timeless Gold-Plated Layered Necklace ₹399 12% off'},
#  {'product_title': 'Maroon Sweetheart Neck Corset',
#   'product_price': '₹1199',
#   'product_link': 'https://newme.asia/product/maroon-sweetheart-neck-corset',
#   'product_image_url': 'https://assets.newme.asia/wp-content/uploads/2024/08/050525206d4cf79c/NM-PRC-142-BLS-24-JUN-6129-MAROON(1).webp',
#   'product_rating': '★4.9',
#   'product_discount': None,
#   'product_text': 'Maroon Sweetheart Neck Corset ₹1199'},
#  {'product_title': 'Offwhite Knot Detailed Waistline Shorts',
#   'product_price': '₹1299',
#   'product_link': 'https://newme.asia/product/offwhite-knot-detailed-waistline-shorts',
#   'product_image_url': 'https://assets.newme.asia/wp-content/uploads/2025/05/18083832ff694147/NM-IN-56-SHO-25-FEB-12819-OFFWHITE_(1).webp',
#   'product_rating': '★4.6',
#   'product_discount': None,
#   'product_text': 'Offwhite Knot Detailed Waistline Shorts ₹1299'},
#  {'product_title': 'White Solid Spread Collar Oversized Shirt',
#   'product_price': '₹749',
#   'product_link': 'https://newme.asia/product/white-solid-spread-collar-oversized-shirt',
#   'product_image_url': 'https://assets.newme.asia/wp-content/uploads/2025/06/021745439b925e2c/NM-IN-56-SHT-24-SEP-9219-WHITE(1).webp',
#   'product_rating': '★4.8',
#   'product_discount': '7% off',
#   'product_text': 'White Solid Spread Collar Oversized Shirt ₹749 7% off'},
#  {'product_title': 'White Notched Collar Blazer',
#   'product_price': '₹1799',
#   'product_link': 'https://newme.asia/product/white-notched-collar-blazer',
#   'product_image_url': 'https://assets.newme.asia/wp-content/uploads/2025/05/1717105929196bc8/NM-PRC-313-BLZ-25-APR-18093-WHITE(1).webp',
#   'product_rating': '★4.6',
#   'product_discount': '7% off',
#   'product_text': 'White Notched Collar Blazer ₹1799 7% off'},
#  {'product_title': 'Gold Imitation Chain Link Ring',
#   'product_price': '₹249',
#   'product_link': 'https://newme.asia/product/gold-imitation-chain-link-ring',
#   'product_image_url': 'https://assets.newme.asia/wp-content/uploads/2025/05/17111616cc30ae67/NM-PRC-205-RNG-25-FEB-2769-GOLD(1).webp',
#   'product_rating': '★4.7',
#   'product_discount': '17% off',
#   'product_text': 'Gold Imitation Chain Link Ring ₹249 17% off'},
#  {'product_title': 'Black Fit And Flare Maxi Dress',
#   'product_price': '₹799',
#   'product_link': 'https://newme.asia/product/black-fit-and-flare-maxi-dress',
#   'product_image_url': 'https://assets.newme.asia/wp-content/uploads/2025/06/021851535eeb7306/NM-IN-56-DRS-24-APR-4656-BLACK(1).webp',
#   'product_rating': '★4.7',
#   'product_discount': '46% off',
#   'product_text': 'Black Fit And Flare Maxi Dress ₹799 46% off'},
#  {'product_title': 'Gold Imitation Rhinestones Dangle Earrings',
#   'product_price': '₹299',
#   'product_link': 'https://newme.asia/product/gold-imitation-rhinestones-dangle-earrings',
#   'product_image_url': 'https://assets.newme.asia/wp-content/uploads/2025/05/18095057fe99b03c/NM-PRC-204-ERG-25-APR-3120-GOLD(1).webp',
#   'product_rating': '★4.6',
#   'product_discount': None,
#   'product_text': 'Gold Imitation Rhinestones Dangle Earrings ₹299'},
#  {'product_title': 'Imitation Gold Star Ring',
#   'product_price': '₹249',
#   'product_link': 'https://newme.asia/product/imitation-gold-star-ring',
#   'product_image_url': 'https://assets.newme.asia/wp-content/uploads/2025/05/171116022937768d/NM-PRC-205-RNG-25-FEB-2766-GOLD(1).webp',
#   'product_rating': '★4.5',
#   'product_discount': '17% off',
#   'product_text': 'Imitation Gold Star Ring ₹249 17% off'},
#  {'product_title': 'Red Solid Maxi Straight Skirt',
#   'product_price': '₹949',
#   'product_link': 'https://newme.asia/product/red-solid-maxi-straight-skirt',
#   'product_image_url': 'https://assets.newme.asia/wp-content/uploads/2025/05/1809493382c16944/NM-PRC-84-SKT-25-APR-15927-RED(1).webp',
#   'product_rating': '★5.0',
#   'product_discount': '16% off',
#   'product_text': 'Red Solid Maxi Straight Skirt ₹949 16% off'},
#  {'product_title': 'Red Solid Tie Up Corset Top',
#   'product_price': '₹1299',
#   'product_link': 'https://newme.asia/product/red-solid-tie-up-corset-top',
#   'product_image_url': 'https://assets.newme.asia/wp-content/uploads/2024/10/040911400b2b99e1/NM-PRC-135-BLS-24-SEP-9712-RED(1).webp',
#   'product_rating': '★4.8',
#   'product_discount': None,
#   'product_text': 'Red Solid Tie Up Corset Top ₹1299'},
#  {'product_title': 'Imitation Elegance Pearl Pendant Necklace',
#   'product_price': '₹199',
#   'product_link': 'https://newme.asia/product/imitation-elegance-pearl-pendant-necklace',
#   'product_image_url': 'https://assets.newme.asia/wp-content/uploads/2025/05/1811455940ab1b21/NM-PRC-217-NCK-25-MAY-18786-GOLD_(1).webp',
#   'product_rating': '★4.8',
#   'product_discount': None,
#   'product_text': 'Imitation Elegance Pearl Pendant Necklace ₹199'},
#  {'product_title': 'White Twisted Detail Halter Neck Dress',
#   'product_price': '₹1499',
#   'product_link': 'https://newme.asia/product/white-twisted-detail-halter-neck-dress',
#   'product_image_url': 'https://assets.newme.asia/wp-content/uploads/2025/07/02073957c728a988/NM-PRC-118-DRS-25-FEB-14148-WHITE(1)_exp.webp',
#   'product_rating': '★4.8',
#   'product_discount': None,
#   'product_text': 'White Twisted Detail Halter Neck Dress ₹1499'},
#  {'product_title': 'Imitation Gold Heart Stud Earrings',
#   'product_price': '₹249',
#   'product_link': 'https://newme.asia/product/imitation-gold-heart-stud-earrings-2',
#   'product_image_url': 'https://assets.newme.asia/wp-content/uploads/2025/05/180951252e9baf52/NM-PRC-204-ERG-25-APR-3129-GOLD(1).webp',
#   'product_rating': '★4.4',
#   'product_discount': None,
#   'product_text': 'Imitation Gold Heart Stud Earrings ₹249'},
#  {'product_title': 'Imitation Gold Sun Chain Link Bracelet',
#   'product_price': '₹299',
#   'product_link': 'https://newme.asia/product/imitation-gold-sun-chain-link-bracelet',
#   'product_image_url': 'https://assets.newme.asia/wp-content/uploads/2025/05/17103258929eee2d/NM-PRC-204-BRC-25-FEB-2654-GOLD(1).webp',
#   'product_rating': None,
#   'product_discount': None,
#   'product_text': 'Imitation Gold Sun Chain Link Bracelet ₹299'}]

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
import time

# %%
def parse_jiomart(url):

    options = Options()
    options.add_argument("--headless")
    options.add_argument("--disable-gpu")
    options.add_argument("--no-sandbox")

    print(f"Launching Chrome to fetch: {url}")
    driver = webdriver.Chrome(options=options)
    driver.get(url)

    time.sleep(5)

    rendered_html = driver.page_source
    tree = html.fromstring(rendered_html)
    driver.quit()

    product_cards = tree.xpath('//*[@id="algolia_hits"]/div/ol/li')

    products = []

    for i, prod in enumerate(product_cards):
        try:
            title_raw = ''.join(prod.xpath('.//div[2]/div[2]/div/div[1]//text()')).strip()

            if "sponsored" in title_raw:
                title = ''.join(prod.xpath('.//div[2]/div[2]/div/div[2]//text()')).strip()
                if not title:
                    continue
                price = ''.join(prod.xpath('.//div[2]/div[2]/div/div[3]/div[1]/span[1]//text()')).strip()
            else:
                title = title_raw
                if not title:
                    continue
                price = ''.join(prod.xpath('.//div[2]/div[2]/div/div[2]/div[1]/span[1]//text()')).strip()

            discount = ''.join(prod.xpath('.//div[2]/div[2]/div/div[2]/div[2]/span//text()')).strip()

            img = prod.xpath('.//div[2]/div[1]/div/div[1]/img/@src')
            img = img[0] if img else None

            link = prod.xpath('.//a/@href')
            link = "https://www.jiomart.com" + link[0] if link and not link[0].startswith("http") else link[0] if link else None

            product_text = f"{title} {price} {discount}".strip()

            products.append({
                "product_title": title,
                "product_price": price,
                "product_link": link,
                "product_image_link": img,
                "product_rating": None,
                "product_discount": discount or None,
                "product_text": product_text
            })
        except Exception as e:
            print(f"Error parsing product {i+1}:", e)
    return products
parse_jiomart("https://www.jiomart.com/c/homeandkitchen/home-furnishing/bedding/31421")
# Out:
# Launching Chrome to fetch: https://www.jiomart.com/c/homeandkitchen/home-furnishing/bedding/31421
# [{'product_title': 'Sleepsia Memory Foam Wedge Pillow - Orthopedic Back & Neck Pain Relief, Acid Reflux & Post-Surgery Support, Adjustable Leg Elevation Cushion (Blue/Grey)',
#   'product_price': '₹815.00',
#   'product_link': 'https://www.jiomart.com/p/homeandkitchen/sleepsia-memory-foam-orthopedic-bed-wedge-pillow-leg-elevation-incline-pillow-for-back-support-blue-grey/607958019',
#   'product_image_link': 'https://www.jiomart.com/images/product/original/rvjbpus5fp/sleepsia-memory-foam-wedge-pillow-orthopedic-back-neck-pain-relief-acid-reflux-post-surgery-support-adjustable-leg-elevation-cushion-blue-grey-product-images-orvjbpus5fp-p607958019-0-202505302309.jpg?im=Resize=(360,360)',
#   'product_rating': None,
#   'product_discount': '72% OFF',
#   'product_text': 'Sleepsia Memory Foam Wedge Pillow - Orthopedic Back & Neck Pain Relief, Acid Reflux & Post-Surgery Support, Adjustable Leg Elevation Cushion (Blue/Grey) ₹815.00 72% OFF'},
#  {'product_title': 'Sleepsia Soft Luxurious Microfiber Hotel Pillow - Comfortable Pillow for Sleeping, Back & Stomach Sleepers Fluffy Pillow for Bed & Side Sleepers (Pack of 2)',
#   'product_price': '₹799.00',
#   'product_link': 'https://www.jiomart.com/p/homeandkitchen
00',
#   'product_link': 'https://www.jiomart.com/p/homeandkitchen/sleepsia-lounge-premium-100-cotton-vibrant-abstract-art-queen-bedsheet-soft-breathable-wrinkle-resistant-double-bedsheets-180-tc-multi-colour/611146679',
#   'product_image_link': 'https://www.jiomart.com/images/product/original/rvbesxtzua/sleepsia-lounge-premium-100-cotton-vibrant-abstract-art-queen-bedsheet-soft-breathable-wrinkle-resistant-double-bedsheets-180-tc-multi-colour-product-images-orvbesxtzua-p611146679-0-202503121843.jpg?im=Resize=(360,360)',
#   'product_rating': None,
#   'product_discount': None,
#   'product_text': 'Sleepsia Lounge 100% Cotton Queen Bedsheet - Vibrant Abstract Art Print, Soft Breathable 180 TC, Wrinkle & Fade Resistant, Deep Pocket Luxury Hotel Quality Double Bed Sheet Set (Multi-Color) ₹749.00'},
#  {'product_title': 'Sleepsia Microfiber Hotel Pillow for Sleeping - Ultra Soft & Supportive Bed Pillows for Back, Side & Stomach Sleepers, Hypoallergenic 24x16 Pillow (White, Pack of 1)',
#   'product_price': '₹230.00',
#   'product_link': 'https://www.jiomart.com/p/homeandkitchen/sleepsia-microfiber-hotel-pillow-for-sleeping-ultra-soft-bed-pillows-24-x-16-white-pack-of-1/600985266',
#   'product_image_link': '/assets/global/jiomart-default-image-240x285.png',
#   'product_rating': None,
#   'product_discount': '76% OFF',
#   'product_text': 'Sleepsia Microfiber Hotel Pillow for Sleeping - Ultra Soft & Supportive Bed Pillows for Back, Side & Stomach Sleepers, Hypoallergenic 24x16 Pillow (White, Pack of 1) ₹230.00 76% OFF'},
#  {'product_title': 'Status Contract Cotton Rich Double Bedsheet with 2 Pillow Covers for Bed Room, Home, Hotel-120 GSM (Orange)',
#   'product_price': '₹199.00',
#   'product_link': 'https://www.jiomart.com/p/homeandkitchen/status-contract-cotton-rich-double-bedsheet-with-2-pillow-covers-for-bed-room-home-hotel-120-gsm-orange/610593983',
#   'product_image_link': '/assets/global/jiomart-default-image-240x285.png',
#   'product_rating': None,
#   'product_discount': '75% OFF',
#   'product_text': 'Status Contract Cotton Rich Double Bedsheet with 2 Pillow Covers for Bed Room, Home, Hotel-120 GSM (Orange) ₹199.00 75% OFF'},
#  {'product_title': 'Decent Home Polycotton 3D Printed Single Bedsheet with 1 Pillow covers (228 x 152 cm) Blue',
#   'product_price': '₹149.00',
#   'product_link': 'https://www.jiomart.com/p/homeandkitchen/decent-home-polycotton-3d-printed-single-bedsheet-with-1-pillow-covers-228-x-152-cm-blue/599918273',
#   'product_image_link': '/assets/global/jiomart-default-image-240x285.png',
#   'product_rating': None,
#   'product_discount': '81% OFF',
#   'product_text': 'Decent Home Polycotton 3D Printed Single Bedsheet with 1 Pillow covers (228 x 152 cm) Blue ₹149.00 81% OFF'},
#  {'product_title': 'Sleepsia Cooling Gel Wedge Pillow - Adjustable Orthopedic Memory Foam Cushion for Back & Neck Pain Relief, Acid Reflux, Post-Surgery Support (Black/Grey)',
#   'product_price': '₹899.00',
#   'product_link': 'https://www.jiomart.com/p/homeandkitchen/sleepsia-gel-infused-wedge-incline-pillow-back-support-leg-elevation-sleeping-orthopedic-cushion-black-grey/609019459',
#   'product_image_link': '/assets/global/jiomart-default-image-240x285.png',
#   'product_rating': None,
#   'product_discount': '77% OFF',
#   'product_text': 'Sleepsia Cooling Gel Wedge Pillow - Adjustable Orthopedic Memory Foam Cushion for Back & Neck Pain Relief, Acid Reflux, Post-Surgery Support (Black/Grey) ₹899.00 77% OFF'},
#  {'product_title': 'Decent Home Polycotton 3D Printed Single Bedsheet with 1 Pillow covers (228 x 152 cm) Multicolour',
#   'product_price': '₹149.00',
#   'product_link': 'https://www.jiomart.com/p/homeandkitchen/decent-home-polycotton-3d-printed-single-bedsheet-with-1-pillow-covers-228-x-152-cm-multicolour/599918359',
#   'product_image_link': '/assets/global/jiomart-default-image-240x285.png',
#   'product_rating': None,
#   'product_discount': '81% OFF',
#   'product_text': 'Decent Home Polycotton 3D Printed Single Bedsheet with 1 Pillow covers (228 x 152 cm) Multicolour ₹149.00 81% OFF'},
#  {'product_title': 'Sleepsia Cooling Gel Wedge Pillow - Adjustable Orthopedic Memory Foam Cushion for Back & Neck Pain Relief, Acid Reflux, Post-Surgery Support (Black/Grey)',
#   'product_price': '₹899.00',
#   'product_link': 'https://www.jiomart.com/p/homeandkitchen/sleepsia-gel-infused-wedge-incline-pillow-back-support-leg-elevation-sleeping-orthopedic-cushion-black-grey/609019459',
#   'product_image_link': '/assets/global/jiomart-default-image-240x285.png',
#   'product_rating': None,
#   'product_discount': None,
#   'product_text': 'Sleepsia Cooling Gel Wedge Pillow - Adjustable Orthopedic Memory Foam Cushion for Back & Neck Pain Relief, Acid Reflux, Post-Surgery Support (Black/Grey) ₹899.00'}]

# %%
def parse_croma(url):
    tree = get_html_tree(url)
    if tree is None:
        return []
    products = []
    product_divs = tree.xpath('//li[contains(@class,"product-item")]')

    for prod in product_divs:
        try:
            title = ''.join(prod.xpath('.//h3/a/text()')).strip()
            price = ''.join(prod.xpath('.//div[2]/div[2]/div[1]/div/span//text()')).strip()
            link = prod.xpath('.//a/@href')[0]
            link = "https://www.croma.com" + link if link.startswith("/") else link
            img = ''.join(prod.xpath('//img[contains(@src, ".png")]')).strip()
            img = img[0] if img else None
            rating = None
            discount = ''.join(prod.xpath('.//div[2]/div[2]/div[2]/span[3]//text()')).strip()
            text = f"{title} {price} {discount}".strip()

            products.append({
                "product_title": title,
                "product_price": price,
                "product_link": link,
                "product_image_link": img,
                "product_rating": rating,
                "product_discount": discount,
                "product_text": text
            })
        except Exception as e:
            print(f"Error parsing product: {e}")
            continue

    return products
parse_croma("https://www.croma.com/computers-tablets/laptops/gaming-laptops/c/806?q=%3Arelevance&srsltid=AfmBOorNua7Lm5pY1gIccoWx_DjcorgjhEhEjsEgItVLHnXE_lHwnwMT")
# Out:
# [{'product_title': 'Lenovo LOQ 15IRX9 Intel Core i5 13th Gen Gaming Laptop (24GB, 512GB SSD, Windows 11 Home, 6GB Graphics, 15.6 inch 144 Hz Full HD IPS Display, NVIDIA GeForce RTX 4050, MS Office 2021, Luna Grey, 2.38 KG)',
#   'product_price': '₹87,990',
#   'product_link': 'https://www.croma.com/lenovo-loq-15irx9-intel-core-i5-13th-gen-gaming-laptop-24gb-512gb-ssd-windows-11-home-6gb-graphics-15-6-inch-144-hz-full-hd-ips-display-nvidia-geforce-rtx-4050-ms-office-2021-luna-grey-2-38-kg-/p/307439',
#   'product_image_link': None,
#   'product_rating': None,
#   'product_discount': '30% Off',
#   'product_text': 'Lenovo LOQ 15IRX9 Intel Core i5 13th Gen Gaming Laptop (24GB, 512GB SSD, Windows 11 Home, 6GB Graphics, 15.6 inch 144 Hz Full HD IPS Display, NVIDIA GeForce RTX 4050, MS Office 2021, Luna Grey, 2.38 KG) ₹87,990 30% Off'},
#  {'product_title': 'HP Vectus 16-s0089AX AMD Ryen 7 Laptop (16GB, 1TB, Windows 11 Home, 16.1 inch Full HD IPS Display, MS Office 2021, Performance Blue, 2.29 KG)',
#   'product_price': '₹78,990',
#   'product_link': 'https://www.croma.com/hp-vectus-16-s0089ax-amd-ryen-7-laptop-16gb-1tb-windows-11-home-16-1-inch-full-hd-ips-display-ms-office-2021-performance-blue-2-29-kg-/p/275369',
#   'product_image_link': None,
#   'product_rating': None,
#   'product_discount':
Gen Gaming Laptop (16GB, 512GB SSD, Windows 11 Home, 6GB Graphics, 16 inch 165 Hz WUXGA IPS Display, NVIDIA GeForce RTX 4050, Abyssal Black, 2.8 KG) ₹1,14,990 21% Off'},
#  {'product_title': 'HP Victus FA1198TX Intel Core i5 13th Gen Gaming Laptop (16GB, 512GB SSD, Windows 11 Home, 6GB Graphics, 15.6 inch 144 Hz Full HD Display, NVIDIA GeForce RTX 3050, MS Office, Meca Silver, 2.29 KG)',
#   'product_price': '₹72,990',
#   'product_link': 'https://www.croma.com/hp-victus-fa1198tx-intel-core-i5-13th-gen-gaming-laptop-16gb-512gb-ssd-windows-11-home-6gb-graphics-15-6-inch-144-hz-full-hd-display-nvidia-geforce-rtx-3050-ms-office-meca-silver-2-29-kg-/p/312484',
#   'product_image_link': None,
#   'product_rating': None,
#   'product_discount': '16% Off',
#   'product_text': 'HP Victus FA1198TX Intel Core i5 13th Gen Gaming Laptop (16GB, 512GB SSD, Windows 11 Home, 6GB Graphics, 15.6 inch 144 Hz Full HD Display, NVIDIA GeForce RTX 3050, MS Office, Meca Silver, 2.29 KG) ₹72,990 16% Off'},
#  {'product_title': 'Lenovo LOQ 15IAX9 Intel Core i5 12th Gen Gaming Laptop (12GB, 512GB SSD, Windows 11 Home, 4GB Graphics, 15.6 inch 144 Hz Full HD IPS Display, NVIDIA GeForce RTX 2050, MS Office Home & Student, Luna Grey, 2.38 KG)',
#   'product_price': '₹63,490',
#   'product_link': 'https://www.croma.com/lenovo-loq-15iax9-intel-core-i5-12th-gen-gaming-laptop-12gb-512gb-ssd-windows-11-home-4gb-graphics-15-6-inch-144-hz-full-hd-ips-display-nvidia-geforce-rtx-2050-ms-office-home-student-luna-grey-2-38-kg-/p/305669',
#   'product_image_link': None,
#   'product_rating': None,
#   'product_discount': '31% Off',
#   'product_text': 'Lenovo LOQ 15IAX9 Intel Core i5 12th Gen Gaming Laptop (12GB, 512GB SSD, Windows 11 Home, 4GB Graphics, 15.6 inch 144 Hz Full HD IPS Display, NVIDIA GeForce RTX 2050, MS Office Home & Student, Luna Grey, 2.38 KG) ₹63,490 31% Off'},
#  {'product_title': 'Lenovo LOQ 15IAX9 Intel Core i5 12th Gen Gaming Laptop (16GB, 512GB SSD, Windows 11 Home, 6GB Graphics, 15.6 inch 144 Hz Full HD IPS Display, NVIDIA GeForce RTX 3050, MS Office Home & Student 2021, Luna Grey, 2.38 KG)',
#   'product_price': '₹70,990',
#   'product_link': 'https://www.croma.com/lenovo-loq-15iax9-intel-core-i5-12th-gen-gaming-laptop-16gb-512gb-ssd-windows-11-home-6gb-graphics-15-6-inch-144-hz-full-hd-ips-display-nvidia-geforce-rtx-3050-ms-office-home-student-2021-luna-grey-2-38-kg-/p/305682',
#   'product_image_link': None,
#   'product_rating': None,
#   'product_discount': '33% Off',
#   'product_text': 'Lenovo LOQ 15IAX9 Intel Core i5 12th Gen Gaming Laptop (16GB, 512GB SSD, Windows 11 Home, 6GB Graphics, 15.6 inch 144 Hz Full HD IPS Display, NVIDIA GeForce RTX 3050, MS Office Home & Student 2021, Luna Grey, 2.38 KG) ₹70,990 33% Off'},
#  {'product_title': 'DELL G15-5530 Intel Core i5 13th Gen Gaming Laptop with RGB Keyboard(16GB, 512GB SSD, Windows 11, 6GB Graphics, 15.6 inch 120 Hz FHD Display, MS Office 2021, Dark Shadow Gray, 2.97 KG)',
#   'product_price': '₹75,990',
#   'product_link': 'https://www.croma.com/dell-g15-5530-intel-core-i5-13th-gen-gaming-laptop-with-rgb-keyboard-16gb-512gb-ssd-windows-11-6gb-graphics-15-6-inch-120-hz-fhd-display-ms-office-2021-dark-shadow-gray-2-97-kg-/p/273309',
#   'product_image_link': None,
#   'product_rating': None,
#   'product_discount': '29% Off',
#   'product_text': 'DELL G15-5530 Intel Core i5 13th Gen Gaming Laptop with RGB Keyboard(16GB, 512GB SSD, Windows 11, 6GB Graphics, 15.6 inch 120 Hz FHD Display, MS Office 2021, Dark Shadow Gray, 2.97 KG) ₹75,990 29% Off'},
#  {'product_title': 'HP Victus 15-fb0178AX AMD Ryzen 5 5600H Gaming Laptop (16GB, 512GB SSD, Windows 11 Home, 4GB Graphics, 15.6 inch 144 Hz Full HD Display, NVIDIA GeForce RTX 3050, Performance Blue, 2.29 KG)',
#   'product_price': '₹59,990',
#   'product_link': 'https://www.croma.com/hp-victus-15-fb0178ax-amd-ryzen-5-5600h-gaming-laptop-16gb-512gb-ssd-windows-11-home-4gb-graphics-15-6-inch-144-hz-full-hd-display-nvidia-geforce-rtx-3050-performance-blue-2-29-kg-/p/312486',
#   'product_image_link': None,
#   'product_rating': None,
#   'product_discount': '21% Off',
#   'product_text': 'HP Victus 15-fb0178AX AMD Ryzen 5 5600H Gaming Laptop (16GB, 512GB SSD, Windows 11 Home, 4GB Graphics, 15.6 inch 144 Hz Full HD Display, NVIDIA GeForce RTX 3050, Performance Blue, 2.29 KG) ₹59,990 21% Off'},
#  {'product_title': 'HP OMEN 16-xd0015AX AMD Ryzen 7 7840HS Gaming Laptop (16GB, 1TB SSD, Windows 11 Home, 6GB Graphics, 16.1 inch 165 Hz Full HD Display, NVIDIA GeForce RTX 4050, MS Office 2021, Shadow Black, 2.37 KG)',
#   'product_price': '₹97,990',
#   'product_link': 'https://www.croma.com/hp-omen-16-xd0015ax-amd-ryzen-7-7840hs-gaming-laptop-16gb-1tb-ssd-windows-11-home-6gb-graphics-16-1-inch-165-hz-full-hd-display-nvidia-geforce-rtx-4050-ms-office-2021-shadow-black-2-37-kg-/p/312418',
#   'product_image_link': None,
#   'product_rating': None,
#   'product_discount': '22% Off',
#   'product_text': 'HP OMEN 16-xd0015AX AMD Ryzen 7 7840HS Gaming Laptop (16GB, 1TB SSD, Windows 11 Home, 6GB Graphics, 16.1 inch 165 Hz Full HD Display, NVIDIA GeForce RTX 4050, MS Office 2021, Shadow Black, 2.37 KG) ₹97,990 22% Off'}]

# %%
def parse_nike(url):
    headers = {"User-Agent": "Mozilla/5.0"}
    tree = get_html_tree(url, headers)
    if tree is None:
        return []

    products = []
    product_divs = tree.xpath('//div[contains(@class,"product-card product-grid__card")]')

    for prod in product_divs:
        try:
            title = ''.join(prod.xpath('.//div[@class="product-card__title"]/text()')).strip()
            price = ''.join(prod.xpath('.//div[contains(@class, "product-price")]//text()')).strip()
            link = prod.xpath('.//a/@href')[0]
            link = "https://www.nike.com" + link if link.startswith("/") else link
            img = prod.xpath('.//img[contains(@class, "product-card__hero-image")]/@data-src')
            if not img:
                img = prod.xpath('.//img[contains(@class, "product-card__hero-image")]/@src')
            img = img[0] if img else None
            rating = None
            discount = None
            subtitle= ''.join(prod.xpath('.//div[@class="product-card__subtitle"]/text()')).strip()
            text = f"{title} {subtitle} {price} {discount}".strip()
            if not title and not link:
                continue
            products.append({
                "product_title": title,
                "product_price": price,
                "product_link": link,
                "product_image_link": img,
                "product_rating": rating or None,
                "product_discount": discount or None,
                "product_text": text
            })
        except Exception as e:
            print(f"Error parsing product: {e}")
            continue

    return products
parse_nike("https://www.nike.com/in/w/mens-nik1")
# Out:
# [{'product_title': 'Nike Revolution 8',
#   'product_price': 'MRP : ₹ 4 295.00',
#   'product_link': 'https://www.nike.com/in/t/revolution-8-road-running-shoes-WMhKGn/HJ9198-101',
#   'product_image_link': '...',
#   'product_rating': None,
#   'product_discount': None,
#   'product_text': "Nike Revolution 8 Men's Road Running Shoes MRP : ₹ 4 295.00 None"},
#  {'product_title': 'Nike Downshifter 13',
#   'product_price': 'MRP : ₹ 4 295.00',
#   'product_link': 'https://www.nike.com/in/t/downshifter-13-road-running-shoes-4Gw85J/FD6454-001',
#   'product_image_link': '...',
#   'product_rating': None,
#   'product_discount': None,
#   'product_text': "Nike Downshifter 13 Men's Road Running Shoes MRP : ₹ 4 295.00 None"},
#  {'product_title': 'Nike SB Force 58',
#   'product_price': 'MRP : ₹ 6 295.00',
#   'product_link': 'https://www.nike.com/in/t/sb-force-58-skate-shoes-6j3JTLx7/IH0636-141',
#   'product_image_link': '...',
#   'product_rating': None,
#   'product_discount': None,
#   'product_text': 'Nike SB Force 58 Skate Shoes MRP : ₹ 6 295.00 None'},
#  {'product_title': 'Nike Court Vision Low',
#   'product_price': 'MRP : ₹ 5 695.00',
#   'product_link': 'https://www.nike.com/in/t/court-vision-low-shoes-q0sr67/FQ8075-133',
#   'product_image_link': '...',
#   'product_rating': None,
#   'product_discount': None,
#   'product_text': "Nike Court Vision Low Men's Shoes MRP : ₹ 5 695.00 None"},
#  {'product_title': 'Nike Air Monarch IV',
#   'product_price': 'MRP : ₹ 5 295.00',
#   'product_link': 'https://www.nike.com/in/t/air-monarch-iv-workout-shoes-cc3XbD/415445-101',
#   'product_image_link': '...',
#   'product_rating': None,
#   'product_discount': None,
#   'product_text': "Nike Air Monarch IV Men's Workout Shoes MRP : ₹ 5 295.00 None"},
#  {'product_title': "Nike Air Force 1 '07",
#   'product_price': 'MRP : ₹ 7 495.00',
#   'product_link': 'https://www.nike.com/in/t/air-force-1-07-shoes-WrLlWX/CW2288-111',
#   'product_image_link': '...',
#   'product_rating': None,
#   'product_discount': None,
#   'product_text': "Nike Air Force 1 '07 Men's Shoes MRP : ₹ 7 495.00 None"},
#  {'product_title': 'Nike Calm',
#   'product_price': 'MRP : ₹ 7 095.00',
#   'product_link': 'https://www.nike.com/in/t/calm-sandals-t1BKK6/FJ6044-001',
#   'product_image_link': '...',
#   'product_rating': None,
#   'product_discount': None,
#   'product_text': "Nike Calm Men's Sandals MRP : ₹ 7 095.00 None"},
#  {'product_title': 'NikeCourt Royale 2 Next Nature',
#   'product_price': 'MRP : ₹ 3 995.00',
#   'product_link': 'https://www.nike.com/in/t/nikecourt-royale-2-next-nature-shoes-RRcr20/DH3160-001',
#   'product_image_link': '...',
#   'product_rating': None,
#   'product_discount': None,
#   'product_text': "NikeCourt Royale 2 Next Nature Men's Shoes MRP : ₹ 3 995.00 None"},
#  {'product_title': 'Nike Go FlyEase',
#   'product_price': 'MRP : ₹ 11 895.00',
#   'product_link': 'https://www.nike.com/in/t/go-flyease-easy-on-off-shoes-3svRCL/DR5540-002',
#   'product_image_link': '...',
#   'product_rating': None,
#   'product_discount': None,
#   'product_text': "Nike Go FlyEase Women's Easy On/Off Shoes MRP : ₹ 11 895.00 None"},
#  {'product_title': 'Nike SB Force 58',
#   'product_price': 'MRP : ₹ 5 995.00',
#   'product_link': 'https://www.nike.com/in/t/sb-force-58-skate-shoe-HNFTvl/CZ2959-003',
#   'product_image_link': '...',
#   'product_rating': None,
#   'product_discount': None,
#   'product_text': 'Nike SB Force 58 Skate Shoe MRP : ₹ 5 995.00 None'},
#  {'product_title': 'Nike Killshot 2 Leather',
#   'product_price': 'MRP : ₹ 7 995.00',
#   'product_link': 'https://www.nike.com/in/t/killshot-2-leather-shoes-DqWZ4j/432997-107',
#   'product_image_link': '...',
#   'product_rating': None,
#   'product_discount': None,
#   'product_text': "Nike Killshot 2 Leather Men's Shoes MRP : ₹ 7 995.00 None"},
#  {'product_title': 'Nike Dunk Low Retro',
#   'product_price': 'MRP : ₹ 8 295.00',
#   'product_link': 'https://www.nike.com/in/t/dunk-low-retro-shoe-66RGqF/DD1391-100',
#   'product_image_link': '...',
#   'product_rating': None,
#   'product_discount': None,
#   'product_text': "Nike Dunk Low Retro Men's Shoe MRP : ₹ 8 295.00 None"},
#  {'product_title': "Luka .77 PF 'Bloodline'",
#   'product_price': 'MRP : ₹ 8 695.00',
#   'product_link': 'https://www.nike.com/in/t/luka-77-pf-bloodline-basketball-shoes-MlPLwJ/HF0819-101',
#   'product_image_link': '...',
#   'product_rating': None,
#   'product_discount': None,
#   'product_text': "Luka .77 PF 'Bloodline' Basketball Shoes MRP : ₹ 8 695.00 None"},
#  {'product_title': 'Nike Pegasus 41',
#   'product_price': 'MRP : ₹ 11 895.00',
#   'product_link': 'https://www.nike.com/in/t/pegasus-41-road-running-shoes-RZm89S/FD2722-001',
#   'product_image_link': '...',
#   'product_rating': None,
#   'product_discount': None,
#   'product_text': "Nike Pegasus 41 Men's Road Running Shoes MRP : ₹ 11 895.00 None"},
#  {'product_title': "Luka .77 PF 'Navigator'",
#   'product_price': 'MRP : ₹ 8 695.00',
#   'product_link': 'https://www.nike.com/in/t/luka-77-pf-navigator-basketball-shoes-kFQixeed/HF0819-002',
#   'product_image_link': '...',
#   'product_rating': None,
#   'product_discount': None,
#   'product_text': "Luka .77 PF 'Navigator' Basketball Shoes MRP : ₹ 8 695.00 None"},
#  {'product_title': 'Nike Court Vision Low Next Nature',
#   'product_price': 'MRP : ₹ 4 995.00',
#   'product_link': 'https://www.nike.com/in/t/court-vision-low-next-nature-shoes-N2fFHb/DH2987-100',
#   'product_image_link': '...',
#   'product_rating': None,
#   'product_discount': None,
#   'product_text': "Nike Court Vision Low Next Nature Men's Shoes MRP : ₹ 4 995.00 None"},
#  {'product_title': 'Air Jordan 1 Low Premium',
#   'product_price': 'MRP : ₹ 11 495.00',
#   'product_link': 'https://www.nike.com/in/t/air-jordan-1-low-shoes-MVVTBG/IB8058-110',
#   'product_image_link': '...',
#   'product_rating': None,
#   'product_discount': None,
#   'product_text': "Air Jordan 1 Low Premium Men's Shoes MRP : ₹ 11 495.00 None"},
#  {'product_title': 'Nike Run Defy',
#   'product_price': 'MRP : ₹ 3 995.00',
#   'product_link': 'https://www.nike.com/in/t/run-defy-road-running-shoes-rVrdTl/HM9594-002',
#   'product_image_link': '...',
#   'product_rating': None,
#   'product_discount': None,
#   'product_text': "Nike Run Defy Men's Road Running Shoes MRP : ₹ 3 995.00 None"},
#  {'product_title': 'Nike Pegasus Premium',
#   'product_price': 'MRP : ₹ 19 295.00',
#   'product_link': 'https://www.nike.com/in/t/pegasus-road-running-shoes-XrUfCtwi/HQ2592-006',
#   'product_image_link': '...',
#   'product_rating': None,
#   'product_discount': None,
#   'product_text': "Nike Pegasus Premium Men's Road Running Shoes MRP : ₹ 19 295.00 None"},
#  {'product_title': 'Nike Air Force 1 Retro',
#   'product_price': 'MRP : ₹ 11 895.00',
#   'product_link': 'https://www.nike.com/in/t/air-force-1-retro-shoes-HRt9QH/IB5722-100',
#   'product_image_link': '...',
#   'product_rating': None,
#   'product_discount': None,
#   'product_text': "Nike Air Force 1 Retro Men's Shoes MRP : ₹ 11 895.00 None"},
#  {'product_title': "Air Jordan 4 Retro 'White Cement'",
#   'product_price': 'MRP : ₹ 19 495.00',
#   'product_link': 'https://www.nike.com/in/t/air-jordan-4-retro-white-cement-shoes-jG6CSt/FV5029-100',
#   'product_image_link': '...',
#   'product_rating': None,
#   'product_discount': None,
#   'product_text': "Air Jordan 4 Retro 'White Cement' Men's Shoes MRP : ₹ 19 495.00 None"},
#  {'product_title': "Nike Air Force 1 '07",
#   'product_price': 'MRP : ₹ 9 695.00',
#   'product_link': 'https://www.nike.com/in/t/air-force-1-07-shoes-0XGfD7/FJ4146-100',
#   'product_image_link': '...',
#   'product_rating': None,
#   'product_discount': None,
#   'product_text': "Nike Air Force 1 '07 Men's Shoes MRP : ₹ 9 695.00 None"},
#  {'product_title': 'Paris Saint-Germain Air Max Dn8 Premium',
#   'product_price': 'MRP : ₹ 18 395.00',
#   'product_link': 'https://www.nike.com/in/t/paris-saint-germain-air-max-dn8-shoes-l7bwxRs2/IH2140-001',
#   'product_image_link': '...',
#   'product_rating': None,
#   'product_discount': None,
#   'product_text': "Paris Saint-Germain Air Max Dn8 Premium Men's Nike Shoes MRP : ₹ 18 395.00 None"},
#  {'product_title': 'Nike Air Max Dn',
#   'product_price': 'MRP : ₹ 15 995.00',
#   'product_link': 'https://www.nike.com/in/t/air-max-dn-shoes-3lJJCZ/IB7025-200',
#   'product_image_link': '...',
#   'product_rating': None,
#   'product_discount': None,
#   'product_text': "Nike Air Max Dn Men's Shoes MRP : ₹ 15 995.00 None"}]

# %%
urls = {
    "NewMe": "https://newme.asia/collection/cannes-2025?subCategory=&product_cat=&orderby=menu_order",
    "JioMart": "https://www.jiomart.com/c/homeandkitchen/home-furnishing/bedding/31421",
    "Croma": "https://www.croma.com/computers-tablets/laptops/gaming-laptops/c/806?srsltid=AfmBOorNua7Lm5pY1gIccoWx_DjcorgjhEhEjsEgItVLHnXE_lHwnwMT",
    "Nike": "https://www.nike.com/in/w/mens-nik1"
}

results = []
results += parse_newme(urls["NewMe"])
results += parse_jiomart(urls["JioMart"])
results += parse_croma(urls["Croma"])
results += parse_nike(urls["Nike"])

print(f"\nTotal Products Fetched: {len(results)}")
pprint(results[:5])
# Out:
# Launching Chrome to fetch: https://www.jiomart.com/c/homeandkitchen/home-furnishing/bedding/31421
#
# Total Products Fetched: 87
# [{'product_discount': '16% off',
#   'product_image_url': 'https://assets.newme.asia/wp-content/uploads/2024/11/23103344714ed636/NM-PRC-34-DRS-24-NOV-11620-GOLD(1).webp',
#   'product_link': 'https://newme.asia/product/gold-shimmer-gown',
#   'product_price': '₹1599',
#   'product_rating': '★4.4',
#   'product_text': 'Gold Shimmer Gown ₹1599 16% off',
#   'product_title': 'Gold Shimmer Gown'},
#  {'product_discount': None,
#   'product_image_url': 'https://assets.newme.asia/wp-content/uploads/2025/05/17103234c2123f49/NM-PRC-215-ERG-25-FEB-2548-MULTI(1).webp',
#   'product_link': 'https://newme.asia/product/multicolor-rhinestone-embellished-drop-earrings',
#   'product_price': '₹199',
#   'product_rating': '★4.7',
#   'product_text': 'Imitation Multicolor Drop Earrings ₹199',
#   'product_title': 'Imitation Multicolor Drop Earrings'},
#  {'product_discount': '21% off',
#   'product_image_url': 'https://assets.newme.asia/wp-content/uploads/2024/11/1614341565eeb505/NM-PRC-135-DRS-24-NOV-11311-BEIGE(1).webp',
#   'product_link': 'https://newme.asia/product/beige-shimmer-halter-neck-gown',
#   'product_price': '₹1749',
#   'product_rating': '★5.0',
#   'product_text': 'Beige Shimmer Halter Neck Gown ₹1749 21% off',
#   'product_title': 'Beige Shimmer Halter Neck Gown'},
#  {'product_discount': None,
#   'product_image_url': 'https://assets.newme.asia/wp-content/uploads/2024/09/1020594343d69f12/NM-PRC-209-NCK-24-SEP-160-MULTI_(1).webp',
#   'product_link': 'https://newme.asia/product/preppy-choker-necklace-with-assorted-charms',
#   'product_price': '₹399',
#   'product_rating': '★4.6',
#   'product_text': 'Imitation Preppy Choker Necklace With Assorted Charms ₹399',
#   'product_title': 'Imitation Preppy Choker Necklace With Assorted Charms'},
#  {'product_discount': '7% off',
#   'product_image_url': 'https://assets.newme.asia/wp-content/uploads/2025/06/02194022c0e84a53/NM-PRC-3-DRS-25-MAR-15035-BLACK(1).webp',
#   'product_link': 'https://newme.asia/product/black-cut-out-detail-bodycon-slip-dress',
#   'product_price': '₹1549',
#   'product_rating': '★4.4',
#   'product_text': 'Black Cut Out Detail Bodycon Slip Dress ₹1549 7% off',
#   'product_title': 'Black Cut Out Detail Bodycon Slip Dress'}]
